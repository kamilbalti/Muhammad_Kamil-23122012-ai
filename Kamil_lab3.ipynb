# %% [markdown]
# <a href="https://colab.research.google.com/github/kamilbalti/Muhammad_Kamil-23122012-ai/blob/main/Kamil_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

from google.colab import userdata
api_key = userdata.get('geminiSecretKey')
client = genai.Client(api_key=api_key)


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Travel Agent Started (type 'exit' to stop)
#
#
# Agent:
#  Hello! Welcome to Pakistan Tourism. As your professional travel agent, I am thrilled to help you plan an unforgettable trip.
#
# Since you are traveling on a student budget, I have designed the ultimate pocket-friendly travel plan for **Hunza Valley (The Crown of Gilgit-Baltistan)**. It is one of the safest, most beautiful, and culturally rich destinations in Pakistan, making it perfect for student groups.
#
# Here is your detailed, easy-to-follow travel plan:
#
# ---
#
# ### 1. Destination Overview
# **Hunza Valley** is a mountainous valley situated in the northern part of Gilgit-Baltistan. Known for its breathtaking snow-capped peaks (like Rakaposhi and Ladyfinger), turquoise lakes, and incredibly hospitable people, Hunza boasts a nearly 100% literacy rate and is extremely safe for travelers.
# *   **Best Time to Visit:** May to October (Summer/Autumn).
# *   **Ideal Trip Duration:** 5 to 7 days (from Islamabad).
#
# ...

# %%
# !pip install -U google-genai
from google import genai

from google.colab import userdata
api_key = userdata.get('geminiSecretKey')
client = genai.Client(api_key=api_key)


MODEL = "models/gemini-3.5-flash"


def smart_room_agent(user_input):
    prompt = f"""
You are a smart room assistant.

Help users manage their room by controlling or suggesting settings for:
- Lights
- Fan
- AC
- Temperature
- Curtains
- TV
- Energy saving

For every request, clearly mention the device, action, and setting.

Keep responses short, simple, and practical.

User request: {user_input}

Smart Room Response:
"""


    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Smart Room Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = smart_room_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Smart Room Agent Started (type 'exit' to stop)
#
# You: Light is on while it is night and ac and room door is on while nobody there
#
# Agent:
#  Since nobody is in the room, I have updated the settings to save energy and secure the room:
#
# *   **Device:** Lights | **Action:** Turn Off | **Setting:** Off
# *   **Device:** AC | **Action:** Turn Off | **Setting:** Off
# *   **Device:** Door | **Action:** Close | **Setting:** Closed
#
# You: Exit
# Goodbye
